# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# Your text goes here

text = """
The copyright and Other Intellectual Property Law Provisions Act 2019 (“the Act”) was signed into law by the president on 26 June 2019. The act amends the Copyright and related rights act 2000 and introduces certain recommendations of the copyright review committee from their 2013 Report, “Modernising Copyright”.

The act confers jurisdiction on the district court and the circuit court to hear and determine intellectual property claims, including claims in relation to copyright infringement. This effectively allows for litigants to bring a claim alleging copyright or IP infringement in a more timely manner and at a significantly lower cost than before, where any such claims were brought before the high court or commercial court.

Section 12
Section 12 of the act revises the existing law relating to “fair dealing” with published work for the purposes of reporting current events. The amendment relaxes the confines of copyright law applying to a “media business” when the business communicates a work which would otherwise be protected by copyright, and that work concerns economic, political or religious matters. The relaxation of the law will apply to such use unless the use of the work is expressly reserved. The use must also be accompanied by a sufficient acknowledgement.

Section 13
Section 13 puts on a statutory footing the defence of fair dealing with copyright-protected work if the use is for the purposes of caricature, parody or pastiche.

Section 14
Section 14 introduces certain exceptions to copyright infringement, where the protected work is used for text and data mining for non-commercial purposes. However, if the copied work is transferred to a third party without the copyright holder’s authorisation or where the protected work is used for a commercial purpose, the copyright will be infringed.

Section 15
Section 15 sets out in detail the exceptions to copyright law where the use of the work is for the purposes of education, teaching or scientific research. There are, however, limitations to these exceptions – notably, these provisions will only apply where the use of the protected work is for non-commercial purposes. The act further extends certain exceptions to the use of copyright-protected work to librarians and archivists where the use of the work is undertaken for education, teaching or research purposes.

Section 22
Section 22 relates to the use of recordings of spoken words, such as lectures and political speeches, for reporting and broadcasting. The use of such material will not infringe copyright law provided the use of the recording was not prohibited by the speaker or copyright owner and provided that the record is a true and direct record of the spoken words.

Section 34
Section 34 extends to licensees the rights and remedies available to copyright holders to pursue copyright infringement proceedings against anyone who infringes copyright in the licensed works. Previously, the burden of enforcing copyright in the relevant works rested exclusively on the copyright holder.

Effect
The signing into law of the act approximately coincides with the passage of the copyright directive through the European parliament. The copyright directive is a more far-reaching reform of copyright law in the digital sphere but is unlikely to be transposed into Irish law before June 2021. For those reproducing copyright works (and reproduction can take many forms), it is important to be aware of the changes that will be affected by both the copyright Act 2019 and the copyright directive, particularly in the context of digital content.

[
Tldr;
Section 12 - Use of work by media business for communication
Section 13 - Use of work for caricature, parody, pastiche
Section 14 - Use of work Text and Data mining for non-commercial purposes only
Section 15 - Use of work for education and archiving for non-commercial purposes only
Section 22 - Using spoken words in political speeches for reporting is not an infringement unless prohibited by the speaker
Section 23 - Licensees can also file for copyright infringement.
(Licensees have specific rights granted by the copyright holder to use the work legally)
Effect - Coincides directly with the copyright directive by EU parliament.
]

How does it affect software:
In general, intellectual property laws, including copyright, play a crucial role in the software industry. Key aspects often covered in such laws include:

Copyright Protection: Intellectual property laws typically provide copyright protection for software, considering it a creative work. This protection prevents unauthorized copying, distribution, or use of software without the permission of the copyright owner.
License and Ownership: The act might define the terms under which software can be licensed, outlining the rights and responsibilities of both the software developer and the end-user. It may also clarify ownership rights and conditions under which a license can be transferred.
Digital Rights Management (DRM): The act may address issues related to DRM, which involves technologies and methods used to control access to and usage of digital content, including software.

Protection Against Piracy: Intellectual property laws often include provisions to combat software piracy, unauthorized distribution, and the use of counterfeit software.

Fair Use and Exceptions: There may be provisions specifying fair use rights and other exceptions to copyright, allowing limited use of copyrighted software for purposes such as education, research, or criticism.

Patent Protection: Some intellectual property laws also cover software patents, protecting novel and non-obvious aspects of software inventions.

Enforcement Mechanisms: The act may detail legal mechanisms and procedures for enforcing intellectual property rights, including legal actions against infringement.

International Considerations: In an increasingly globalized environment, the act might include provisions addressing international aspects of intellectual property, ensuring that software developers are protected beyond national borders.

Understanding and enforcing these aspects of intellectual property law are critical for the software industry. They provide incentives for innovation, protect the rights of creators, and foster a healthy and competitive software ecosystem.

"""

# lowering the text before preprocessing
text = text.lower()

# %% [markdown]
# ### **Text pre-processing**

# %%
import re

# defining function for tokenization
def tokenization(text):
    tokens = re.split('\W+',text)
    return tokens

text = tokenization(text)

# %%
import string
string.punctuation

#defining the function to remove punctuation
def remove_punctuation(text):
    punctuationfree=[i for i in text if i not in string.punctuation]
    return punctuationfree

text = remove_punctuation(text)
text

# %%
import nltk
nltk.download('stopwords')

#Stop words present in the library
stopwords = nltk.corpus.stopwords.words('english')
stopwords[0:10]
['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

#defining the function to remove stopwords from tokenized text
def remove_stopwords(text):
    output= [i for i in text if i not in stopwords]
    return output

text = remove_stopwords(text)
text

# %%
# Stemming
#importing the Stemming function from nltk library
from nltk.stem.porter import PorterStemmer

#defining the object for stemming
porter_stemmer = PorterStemmer()

text = " ".join(text)

#defining a function for stemming
def stemming(text):
    stem_text = [porter_stemmer.stem(word) for word in text]
    return stem_text

text = stemming(text)

# %%
#library that contains punctuation
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

#defining the object for Lemmatization
wordnet_lemmatizer = WordNetLemmatizer()
#defining the function for lemmatization
def lemmatizer(text):
    lemm_text = "".join([wordnet_lemmatizer.lemmatize(word) for word in text])
    return lemm_text

text = lemmatizer(text)
text

# %%
# text = "".join(text)
text

# %%
# WordCloud Generation
word_cloud = WordCloud(collocations = False, background_color = 'white', max_words=25, height=500, width=1000).generate(text)

# %%
# Plotting

plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()
